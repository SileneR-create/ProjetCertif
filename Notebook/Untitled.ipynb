# %%
import pandas as pd

# %%
df_worldbank = pd.read_csv(r"..\DATA\external\donnees_touriste.csv")

# %%
df_worldbank.head()
# Out:
#   pays  Services voyage (% exports de services)  Accès électricité (% pop)  \
# 0  AGO                                 9.923331                       51.1
# 1  BDI                                 2.372476                       11.6
# 2  BGD                                 7.113293                       99.5
# 3  BWA                                69.432982                       76.0
# 4  CAN                                29.408235                      100.0
#
#    Densité de population (hab/km²)  Pop. dans grandes agglomérations (%)  \
# 0                        29.477746                             25.285333
# 1                       533.078271                                   NaN
# 2                      1319.179797                             16.673341
# 3                         4.376412                                   NaN
# 4                         4.560798                             44.802126
#
# ...

# %%
df_worldbank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 24 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   pays                                     41 non-null     object
#  1   Services voyage (% exports de services)  38 non-null     float64
#  2   Accès électricité (% pop)                41 non-null     float64
#  3   Densité de population (hab/km²)          41 non-null     float64
#  4   Pop. dans grandes agglomérations (%)     25 non-null     float64
#  5   Accès Internet (% pop)                   40 non-null     float64
#  6   PIB par habitant (USD)                   41 non-null     float64
#  7   Accès eau potable (% pop)                40 non-null     float64
#  8   Médecins (pour 1000 habitants)           40 non-null     float64
#  9   Dépenses santé par habitant (USD)        40 non-null     float64
# ...

# %%
df_meteo = pd.read_csv(r"..\DATA\processed\meteo.csv")

# %%
df_meteo.head()
# Out:
#     City country code_3L  month  temp_avg  temp_max  temp_min
# 0  Accra   ghana     GHA      1      28.7      33.3      25.8
# 1  Accra   ghana     GHA     10      27.3      31.1      24.4
# 2  Accra   ghana     GHA     11      28.4      32.4      25.2
# 3  Accra   ghana     GHA     12      28.8      33.2      25.7
# 4  Accra   ghana     GHA      2      29.1      33.6      26.3

# %%
df_meteo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1248 entries, 0 to 1247
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   City      1248 non-null   object
#  1   country   1248 non-null   object
#  2   code_3L   1248 non-null   object
#  3   month     1248 non-null   int64
#  4   temp_avg  1248 non-null   float64
#  5   temp_max  1248 non-null   float64
#  6   temp_min  1248 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 68.4+ KB

# %%
df_lifequality = pd.read_csv(r"..\DATA\processed\life_quality.csv")

# %%
df_lifequality.head()
# Out:
#    Classement        Pays  Indice de Qualité de Vie  \
# 0         NaN  Luxembourg                    219.32
# 1         NaN    Pays-Bas                    207.48
# 2         NaN    Danemark                    205.57
# 3         NaN        Oman                    204.30
# 4         NaN      Suisse                    203.95
#
#    Indice du Pouvoir d'Achat  Indice de Sécurité  Indice des soins de santé  \
# 0                     182.53               65.72                      75.33
# 1                     124.91               73.58                      79.28
# 2                     127.20               73.89                      78.47
# 3                     139.80               81.77                      65.11
# 4                     158.68               73.91                      71.73
#
#    Indice du Coût de la Vie  Rapport Prix de l'immobilier/Revenu  \
# 0                     62.43                                 8.88
# ...

# %%
df_lifequality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Classement                             0 non-null      float64
#  1   Pays                                   83 non-null     object
#  2   Indice de Qualité de Vie               83 non-null     float64
#  3   Indice du Pouvoir d'Achat              83 non-null     float64
#  4   Indice de Sécurité                     83 non-null     float64
#  5   Indice des soins de santé              83 non-null     float64
#  6   Indice du Coût de la Vie               83 non-null     float64
#  7   Rapport Prix de l'immobilier/Revenu    83 non-null     float64
#  8   Indice du Temps de Trajet dans Trafic  83 non-null     float64
#  9   Indice de pollution                    83 non-null     float64
# ...

# %%
df_iso = pd.read_csv(r"..\DATA\processed\iso3166.csv")

# %%
df_iso.head()
# Out:
#         pays code_2L code_3L  code_numerique
# 0  ALLEMAGNE      DE     DEU             276
# 1   AUTRICHE      AT     AUT              40
# 2   BELGIQUE      BE     BEL              56
# 3   BULGARIE      BG     BGR             100
# 4     CHYPRE      CY     CYP             196

# %%
df_iso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pays            220 non-null    object
#  1   code_2L         219 non-null    object
#  2   code_3L         220 non-null    object
#  3   code_numerique  220 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 7.0+ KB
